# %%
import pandas as pd, numpy as np

# %%
snap = pd.read_csv('Datasets/Merged_final/nyc_snap_cleaned.csv')

# %%
snap = snap.drop('Unnamed: 0', 1)

# %%
set(snap.columns)
# Out:
# {'American_Indian_and_Alaska_Native_alone_percent',
#  'Asian_alone_percent',
#  'Black_or_African_American_alone_percent',
#  'Employed; Estimate; Population 16 years and over',
#  'Employed; Estimate; Population 16 years and over - AGE - 25 to 44 years',
#  'Employed; Estimate; Population 16 years and over - AGE - 45 to 54 years',
#  'Employed; Estimate; Population 16 years and over - AGE - 55 to 64 years',
#  'Female; Estimate; Total population',
#  'Female; Estimate; Total population - AGE - 10 to 14 years',
#  'Female; Estimate; Total population - AGE - 15 to 19 years',
#  'Female; Estimate; Total population - AGE - 20 to 24 years',
#  'Female; Estimate; Total population - AGE - 25 to 29 years',
#  'Female; Estimate; Total population - AGE - 30 to 34 years',
#  'Female; Estimate; Total population - AGE - 35 to 39 years',
#  'Female; Estimate; Total population - AGE - 40 to 44 years',
#  'Female; Estimate; Total population - AGE - 45 to 49 years',
# ...

# %%
import statsmodels.formula.api as smf
Y = snap[['foodstamp_per_HH']]
X = snap.drop(['foodstamp_per_HH', "Id", "Id2"], axis = 1)

# %%
model = smf.OLS(Y,X).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:       foodstamp_per_HH   R-squared:                       0.838
# Model:                            OLS   Adj. R-squared:                  0.837
# Method:                 Least Squares   F-statistic:                     566.5
# Date:                Wed, 01 Mar 2017   Prob (F-statistic):               0.00
# Time:                        14:22:18   Log-Likelihood:                 17001.
# No. Observations:               12479   AIC:                        -3.377e+04
# Df Residuals:                   12365   BIC:                        -3.293e+04
# Df Model:                         113
# Covariance Type:            nonrobust
# ...
#                                                                                                                                                                            coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ...
